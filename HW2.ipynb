# %% [markdown]
# ## Part I

# %%
#1. Import the standard libraries and others as needed.

from pymongo import MongoClient
from bson.objectid import ObjectId
import pandas as pd
import numpy as np
import datetime

# %%
#2. Connect to MongoDB.
#3. Restore the database from the dump given in the ‘data.zip’ file.

client = MongoClient('localhost', 27017)
print(client.list_database_names())
print(client.patient_db.list_collection_names())
# Out:
# ['admin', 'config', 'local', 'patient_db']
# ['conditions', 'patients']

# %%
#4. Import the ‘patient_data_1.csv’ and ‘patient_data_2.csv’ into pandas DataFrames and harmonize them.
#(1) patient_data_1.csv

data1 = pd.read_csv("patient_data_1.csv")
data1.rename(columns={'Id': '_id'}, inplace=True) #change 'Id' to '_id'
data1['GENDER'].replace('Male', 'M', inplace=True) #change 'Male' to 'M'
data1['GENDER'].replace('Female', 'F', inplace=True) #change 'Female' to 'F'
data1
# Out:
#          _id   BIRTHDATE MARITAL   RACE    ETHNICITY GENDER       CITY  \
# 0    P004753  2012-01-12     NaN  asian     hispanic      F   Westford
# 1    P009495  1961-12-01       M  white  nonhispanic      F    Seekonk
# 2    P010851  1997-10-21     NaN  black  nonhispanic      M     Quincy
# 3    P009020  1975-08-15       M  white  nonhispanic      F  Worcester
# 4    P009779  2020-02-25     NaN  white  nonhispanic      F     Bolton
# ..       ...         ...     ...    ...          ...    ...        ...
# 838  P009210  2003-09-13     NaN  white  nonhispanic      F     Boston
# 839  P009845  2003-11-28     NaN  white  nonhispanic      F    Medford
# 840  P001189  1985-01-10       M  white  nonhispanic      F  Worcester
# 841  P002360  1970-09-15       M  white  nonhispanic      M     Newton
# 842  P001698  1994-09-27     NaN  white  nonhispanic      M   Sterling
#
#                COUNTY          STATE
# 0    Middlesex County  Massachusetts
# 1      Bristol County  Massachusetts
# 2      Norfolk County  Massachusetts
# 3    Worcester County  Massachusetts
# 4    Worcester County  Massachusetts
# ..                ...            ...
# 838    Suffolk County  Massachusetts
# 839  Middlesex County  Massachusetts
# 840  Worcester County  Massachusetts
# 841  Middlesex County  Massachusetts
# 842  Worcester County  Massachusetts
#
# [843 rows x 9 columns]

# %%
#(2) patient_data_2.csv

data2 = pd.read_csv("patient_data_2.csv")
data2.columns = data2.columns.map(lambda x:x.upper()) #change column names to upper case
data2.rename(columns={'ID': '_id'}, inplace=True) #change 'ID' to '_id'
data2['ETHNICITY'].replace('non-hispanic', 'nonhispanic', inplace=True) #change 'non-hispanic' to 'nonhispanic'
data2
# Out:
#          _id   BIRTHDATE MARITAL   RACE    ETHNICITY GENDER             CITY  \
# 0    P005102  1969-05-11       M  white  nonhispanic      F  East Longmeadow
# 1    P001814  1957-12-31       M  white  nonhispanic      M       Somerville
# 2    P000373  1989-07-20       S  white  nonhispanic      F        Cambridge
# 3    P007365  1967-10-26       M  white  nonhispanic      F          Mashpee
# 4    P010311  1965-02-14       M  white  nonhispanic      F       Somerville
# ..       ...         ...     ...    ...          ...    ...              ...
# 452  P005128  1962-10-21       M  white  nonhispanic      M           Boston
# 453  P010979  2000-03-02     NaN  asian  nonhispanic      M           Dracut
# 454  P003574  1978-05-22       M  white  nonhispanic      F       Marshfield
# 455  P007576  2008-11-24     NaN  white  nonhispanic      F       Shrewsbury
# 456  P007953  2000-12-23     NaN  white  nonhispanic      M           Ludlow
#
#                 COUNTY          STATE
# 0       Hampden County  Massachusetts
# 1     Middlesex County  Massachusetts
# 2     Middlesex County  Massachusetts
# 3    Barnstable County  Massachusetts
# 4     Middlesex County  Massachusetts
# ..                 ...            ...
# 452     Suffolk County  Massachusetts
# 453   Middlesex County  Massachusetts
# 454    Plymouth County  Massachusetts
# 455   Worcester County  Massachusetts
# 456     Hampden County  Massachusetts
#
# [457 rows x 9 columns]

# %%
#5. From the ‘patients collection, retrieve the patients who are alive. 
#(1) Print the number of patients retrieved.

pts = client.patient_db.patients
pts.count_documents({'DEATHDATE':{'$exists':False}})
# Out:
# 8700

# %%
#(2) Store them in a DataFrame.

data3 = pd.DataFrame(pts.find({'DEATHDATE':{'$exists':False}}))
data3
# Out:
#           _id   BIRTHDATE MARITAL   RACE    ETHNICITY GENDER           CITY  \
# 0     P000001  2017-08-24     NaN  white  nonhispanic      M    Springfield
# 1     P000002  2016-08-01     NaN  white  nonhispanic      F        Walpole
# 2     P000003  1992-06-30       S  white  nonhispanic      M       Chicopee
# 3     P000004  2004-01-09     NaN  white  nonhispanic      F       Pembroke
# 4     P000005  1996-11-15     NaN  white  nonhispanic      M         Boston
# ...       ...         ...     ...    ...          ...    ...            ...
# 8695  P012343  1960-01-05       M  white  nonhispanic      F         Dennis
# 8696  P012345  1980-11-12       M  white  nonhispanic      F         Malden
# 8697  P012347  1960-11-10       M  black  nonhispanic      F  North Andover
# 8698  P012351  1918-10-20       S  white  nonhispanic      F        Waltham
# 8699  P012352  1941-02-11       S  white  nonhispanic      M         Bourne
#
#                  COUNTY          STATE
# 0        Hampden County  Massachusetts
# 1        Norfolk County  Massachusetts
# 2        Hampden County  Massachusetts
# 3       Plymouth County  Massachusetts
# 4        Suffolk County  Massachusetts
# ...                 ...            ...
# 8695  Barnstable County  Massachusetts
# 8696   Middlesex County  Massachusetts
# 8697       Essex County  Massachusetts
# 8698   Middlesex County  Massachusetts
# 8699  Barnstable County  Massachusetts
#
# [8700 rows x 9 columns]

# %%
#6. Concatenate the above three DataFrames.

cond = pd.concat([data1, data2, data3])
cond = cond.sort_values(by = '_id')
cond
# Out:
#           _id   BIRTHDATE MARITAL   RACE    ETHNICITY GENDER           CITY  \
# 0     P000001  2017-08-24     NaN  white  nonhispanic      M    Springfield
# 1     P000002  2016-08-01     NaN  white  nonhispanic      F        Walpole
# 2     P000003  1992-06-30       S  white  nonhispanic      M       Chicopee
# 3     P000004  2004-01-09     NaN  white  nonhispanic      F       Pembroke
# 4     P000005  1996-11-15     NaN  white  nonhispanic      M         Boston
# ...       ...         ...     ...    ...          ...    ...            ...
# 591   P012346  1990-08-25       M  white  nonhispanic      F         Dennis
# 8697  P012347  1960-11-10       M  black  nonhispanic      F  North Andover
# 249   P012348  1962-08-17       M  asian  nonhispanic      F      Wellesley
# 8698  P012351  1918-10-20       S  white  nonhispanic      F        Waltham
# 8699  P012352  1941-02-11       S  white  nonhispanic      M         Bourne
#
#                  COUNTY          STATE
# 0        Hampden County  Massachusetts
# 1        Norfolk County  Massachusetts
# 2        Hampden County  Massachusetts
# 3       Plymouth County  Massachusetts
# 4        Suffolk County  Massachusetts
# ...                 ...            ...
# 591   Barnstable County  Massachusetts
# 8697       Essex County  Massachusetts
# 249      Norfolk County  Massachusetts
# 8698   Middlesex County  Massachusetts
# 8699  Barnstable County  Massachusetts
#
# [10000 rows x 9 columns]

# %%
#7. Compute the current age of the patients and store them in another column called ‘AGE’. 

cond['BIRTHDATE'] = pd.to_datetime(cond['BIRTHDATE'])
today = datetime.datetime.today().year #this year

cond['AGE'] = today - cond['BIRTHDATE'].dt.year
cond
# Out:
#           _id  BIRTHDATE MARITAL   RACE    ETHNICITY GENDER           CITY  \
# 0     P000001 2017-08-24     NaN  white  nonhispanic      M    Springfield
# 1     P000002 2016-08-01     NaN  white  nonhispanic      F        Walpole
# 2     P000003 1992-06-30       S  white  nonhispanic      M       Chicopee
# 3     P000004 2004-01-09     NaN  white  nonhispanic      F       Pembroke
# 4     P000005 1996-11-15     NaN  white  nonhispanic      M         Boston
# ...       ...        ...     ...    ...          ...    ...            ...
# 591   P012346 1990-08-25       M  white  nonhispanic      F         Dennis
# 8697  P012347 1960-11-10       M  black  nonhispanic      F  North Andover
# 249   P012348 1962-08-17       M  asian  nonhispanic      F      Wellesley
# 8698  P012351 1918-10-20       S  white  nonhispanic      F        Waltham
# 8699  P012352 1941-02-11       S  white  nonhispanic      M         Bourne
#
#                  COUNTY          STATE  AGE
# 0        Hampden County  Massachusetts    6
# 1        Norfolk County  Massachusetts    7
# 2        Hampden County  Massachusetts   31
# 3       Plymouth County  Massachusetts   19
# 4        Suffolk County  Massachusetts   27
# ...                 ...            ...  ...
# 591   Barnstable County  Massachusetts   33
# 8697       Essex County  Massachusetts   63
# 249      Norfolk County  Massachusetts   61
# 8698   Middlesex County  Massachusetts  105
# 8699  Barnstable County  Massachusetts   82
#
# [10000 rows x 10 columns]

# %%
#8. Insert the above DataFrame to a collection named ‘patients_clean’.

client.patient_db.patients_clean.insert_many(cond.to_dict('records'))
print(client.patient_db.list_collection_names())
print(client.patient_db.patients_clean.count())
# Out:
# ['patients_clean', 'conditions', 'patients']
# 10000
# <ipython-input-9-f74d20957fe7>:5: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   print(client.patient_db.patients_clean.count())

# %% [markdown]
# ## Part II

# %%
client = MongoClient('localhost', 27017)
print(client.list_database_names())
print(client.patient_db.list_collection_names())
# Out:
# ['admin', 'config', 'local', 'patient_db']
# ['patients_clean', 'conditions', 'patients']

# %%
#9. Obtain the ID’s of patients that were diagnosed with COVID-19
#(1) 8820 patients diagnosed with COVID-19

cdt = client.patient_db.conditions
cdt.count_documents({'conditions': 'COVID-19'})
# Out:
# 8820

# %%
#(2) ID’s of COVID-19 patients

list(cdt.find({'conditions': 'COVID-19'}, {'_id': 0, 'patient': 1}))
# Out:
# [{'patient': 'P000001'},
#  {'patient': 'P000002'},
#  {'patient': 'P000003'},
#  {'patient': 'P000004'},
#  {'patient': 'P000005'},
#  {'patient': 'P000006'},
#  {'patient': 'P000007'},
#  {'patient': 'P000008'},
#  {'patient': 'P000009'},
#  {'patient': 'P000011'},
#  {'patient': 'P000013'},
#  {'patient': 'P000014'},
#  {'patient': 'P000015'},
#  {'patient': 'P000016'},
#  {'patient': 'P000017'},
#  {'patient': 'P000018'},
#  {'patient': 'P000020'},
#  {'patient': 'P000021'},
#  {'patient': 'P000022'},
#  {'patient': 'P000023'},
#  {'patient': 'P000024'},
#  {'patient': 'P000025'},
#  {'patient': 'P000026'},
#  {'patient': 'P000027'},
#  {'patient': 'P000028'},
#  {'patient': 'P000030'},
#  {'patient': 'P000031'},
#  {'patient': 'P000034'},
#  {'patient': 'P000035'},
#  {'patient': 'P000036'},
#  {'patient': 'P000037'},
#  {'patient': 'P000038'},
#  {'patient': 'P000039'},
#  {'patient': 'P000040'},
#  {'patient': 'P000041'},
#  {'patient': 'P000042'},
#  {'patient': 'P000043'},
#  {'patient': 'P000044'},
#  {'patient': 'P000045'},
#  {'patient': 'P000047'},
#  {'patient': 'P000048'},
#  {'patient': 'P000049'},
#  {'patient': 'P000050'},
#  {'patient': 'P000051'},
#  {'patient': 'P000052'},
#  {'patient': 'P000053'},
#  {'patient': 'P000054'},
#  {'patient': 'P000055'},
#  {'patient': 'P000056'},
#  {'patient': 'P000057'},
#  {'patient': 'P000058'},
#  {'patient': 'P000059'},
#  {'patient': 'P000061'},
#  {'patient': 'P000062'},
#  {'patient': 'P000064'},
#  {'patient': 'P000065'},
#  {'patient': 'P000066'},
#  {'patient': 'P000067'},
#  {'patient': 'P000068'},
#  {'patient': 'P000069'},
#  {'patient': 'P000070'},
#  {'patient': 'P000071'},
#  {'patient': 'P000072'},
#  {'patient': 'P000074'},
#  {'patient': 'P000073'},
#  {'patient': 'P000075'},
#  {'patient': 'P000076'},
#  {'patient': 'P000077'},
#  {'patient': 'P000078'},
#  {'patient': 'P000079'},
#  {'patient': 'P000082'},
#  {'patient': 'P000083'},
#  {'patient': 'P000085'},
#  {'patient': 'P000087'},
#  {'patient': 'P000088'},
#  {'patient': 'P000089'},
#  {'patient': 'P000091'},
#  {'patient': 'P000092'},
#  {'patient': 'P000093'},
#  {'patient': 'P000094'},
#  {'patient': 'P000095'},
#  {'patient': 'P000096'},
#  {'patient': 'P000097'},
#  {'patient': 'P000098'},
#  {'patient': 'P000101'},
#  {'patient': 'P000100'},
#  {'patient': 'P000103'},
#  {'patient': 'P000104'},
#  {'patient': 'P000105'},
#  {'patient': 'P000106'},
#  {'patient': 'P000107'},
#  {'patient': 'P000109'},
#  {'patient': 'P000110'},
#  {'patient': 'P000111'},
#  {'patient': 'P000114'},
#  {'patient': 'P000115'},
#  {'patient': 'P000116'},
#  {'patient': 'P000117'},
#  {'patient': 'P000119'},
#  {'patient': 'P000118'},
#  {'patient': 'P000120'},
#  {'patient': 'P000121'},
#  {'patient': 'P000122'},
#  {'patient': 'P000123'},
#  {'patient': 'P000125'},
#  {'patient': 'P000126'},
#  {'patient': 'P000127'},
#  {'patient': 'P000128'},
#  {'patient': 'P000129'},
#  {'patient': 'P000130'},
#  {'patient': 'P000132'},
#  {'patient': 'P000133'},
#  {'patient': 'P000135'},
#  {'patient': 'P000136'},
#  {'patient': 'P000138'},
#  {'patient': 'P000139'},
#  {'patient': 'P000140'},
#  {'patient': 'P000141'},
#  {'patient': 'P000142'},
#  {'patient': 'P000145'},
#  {'patient': 'P000147'},
#  {'patient': 'P000148'},
#  {'patient': 'P000149'},
#  {'patient': 'P000150'},
#  {'patient': 'P000151'},
#  {'patient': 'P000152'},
#  {'patient': 'P000153'},
#  {'patient': 'P000154'},
#  {'patient': 'P000155'},
#  {'patient': 'P000156'},
#  {'patient': 'P000157'},
#  {'patient': 'P000158'},
#  {'patient': 'P000161'},
#  {'patient': 'P000162'},
#  {'patient': 'P000163'},
#  {'patient': 'P000164'},
#  {'patient': 'P000166'},
#  {'patient': 'P000167'},
#  {'patient': 'P000169'},
#  {'patient': 'P000171'},
#  {'patient': 'P000172'},
#  {'patient': 'P000175'},
#  {'patient': 'P000174'},
#  {'patient': 'P000176'},
#  {'patient': 'P000177'},
#  {'patient': 'P000178'},
#  {'patient': 'P000180'},
#  {'patient': 'P000182'},
#  {'patient': 'P000185'},
#  {'patient': 'P000186'},
#  {'patient': 'P000190'},
#  {'patient': 'P000191'},
#  {'patient': 'P000192'},
#  {'patient': 'P000193'},
#  {'patient': 'P000194'},
#  {'patient': 'P000195'},
#  {'patient': 'P000196'},
#  {'patient': 'P000197'},
#  {'patient': 'P000198'},
#  {'patient': 'P000200'},
#  {'patient': 'P000201'},
#  {'patient': 'P000203'},
#  {'patient': 'P000204'},
#  {'patient': 'P000207'},
#  {'patient': 'P000208'},
#  {'patient': 'P000209'},
#  {'patient': 'P000210'},
#  {'patient': 'P000211'},
#  {'patient': 'P000212'},
#  {'patient': 'P000213'},
#  {'patient': 'P000214'},
#  {'patient': 'P000217'},
#  {'patient': 'P000219'},
#  {'patient': 'P000220'},
#  {'patient': 'P000222'},
#  {'patient': 'P000224'},
#  {'patient': 'P000225'},
#  {'patient': 'P000226'},
#  {'patient': 'P000227'},
#  {'patient': 'P000228'},
#  {'patient': 'P000229'},
#  {'patient': 'P000230'},
#  {'patient': 'P000231'},
#  {'patient': 'P000233'},
#  {'patient': 'P000232'},
#  {'patient': 'P000234'},
#  {'patient': 'P000235'},
#  {'patient': 'P000237'},
#  {'patient': 'P000240'},
#  {'patient': 'P000243'},
#  {'patient': 'P000244'},
#  {'patient': 'P000245'},
#  {'patient': 'P000246'},
#  {'patient': 'P000248'},
#  {'patient': 'P000249'},
#  {'patient': 'P000250'},
#  {'patient': 'P000251'},
#  {'patient': 'P000253'},
#  {'patient': 'P000255'},
#  {'patient': 'P000258'},
#  {'patient': 'P000261'},
#  {'patient': 'P000262'},
#  {'patient': 'P000264'},
#  {'patient': 'P000266'},
#  {'patient': 'P000269'},
#  {'patient': 'P000270'},
#  {'patient': 'P000273'},
#  {'patient': 'P000275'},
#  {'patient': 'P000276'},
#  {'patient': 'P000277'},
#  {'patient': 'P000278'},
#  {'patient': 'P000279'},
#  {'patient': 'P000281'},
#  {'patient': 'P000282'},
#  {'patient': 'P000283'},
#  {'patient': 'P000284'},
#  {'patient': 'P000285'},
#  {'patient': 'P000286'},
#  {'patient': 'P000287'},
#  {'patient': 'P000289'},
#  {'patient': 'P000290'},
#  {'patient': 'P000291'},
#  {'patient': 'P000293'},
#  {'patient': 'P000294'},
#  {'patient': 'P000295'},
#  {'patient': 'P000296'},
#  {'patient': 'P000297'},
#  {'patient': 'P000299'},
#  {'patient': 'P000300'},
#  {'patient': 'P000301'},
#  {'patient': 'P000302'},
#  {'patient': 'P000303'},
#  {'patient': 'P000304'},
#  {'patient': 'P000305'},
#  {'patient': 'P000306'},
#  {'patient': 'P000308'},
#  {'patient': 'P000310'},
#  {'patient': 'P000311'},
#  {'patient': 'P000312'},
#  {'patient': 'P000314'},
#  {'patient': 'P000315'},
#  {'patient': 'P000317'},
#  {'patient': 'P000318'},
#  {'patient': 'P000321'},
#  {'patient': 'P000322'},
#  {'patient': 'P000323'},
#  {'patient': 'P000324'},
#  {'patient': 'P000325'},
#  {'patient': 'P000326'},
#  {'patient': 'P000328'},
#  {'patient': 'P000329'},
#  {'patient': 'P000330'},
#  {'patient': 'P000332'},
#  {'patient': 'P000333'},
#  {'patient': 'P000334'},
#  {'patient': 'P000335'},
#  {'patient': 'P000336'},
#  {'patient': 'P000338'},
#  {'patient': 'P000339'},
#  {'patient': 'P000340'},
#  {'patient': 'P000345'},
#  {'patient': 'P000344'},
#  {'patient': 'P000346'},
#  {'patient': 'P000347'},
#  {'patient': 'P000349'},
#  {'patient': 'P000350'},
#  {'patient': 'P000352'},
#  {'patient': 'P000353'},
#  {'patient': 'P000354'},
#  {'patient': 'P000355'},
#  {'patient': 'P000358'},
#  {'patient': 'P000359'},
#  {'patient': 'P000360'},
#  {'patient': 'P000361'},
#  {'patient': 'P000362'},
#  {'patient': 'P000363'},
#  {'patient': 'P000364'},
#  {'patient': 'P000366'},
#  {'patient': 'P000368'},
#  {'patient': 'P000371'},
#  {'patient': 'P000372'},
#  {'patient': 'P000373'},
#  {'patient': 'P000374'},
#  {'patient': 'P000376'},
#  {'patient': 'P000377'},
#  {'patient': 'P000378'},
#  {'patient': 'P000379'},
#  {'patient': 'P000381'},
#  {'patient': 'P000382'},
#  {'patient': 'P000383'},
#  {'patient': 'P000384'},
#  {'patient': 'P000385'},
#  {'patient': 'P000386'},
#  {'patient': 'P000390'},
#  {'patient': 'P000391'},
#  {'patient': 'P000392'},
#  {'patient': 'P000394'},
#  {'patient': 'P000397'},
#  {'patient': 'P000398'},
#  {'patient': 'P000399'},
#  {'patient': 'P000401'},
#  {'patient': 'P000402'},
#  {'patient': 'P000405'},
#  {'patient': 'P000410'},
#  {'patient': 'P000411'},
#  {'patient': 'P000413'},
#  {'patient': 'P000414'},
#  {'patient': 'P000416'},
#  {'patient': 'P000418'},
#  {'patient': 'P000419'},
#  {'patient': 'P000420'},
#  {'patient': 'P000422'},
#  {'patient': 'P000423'},
#  {'patient': 'P000424'},
#  {'patient': 'P000425'},
#  {'patient': 'P000426'},
#  {'patient': 'P000427'},
#  {'patient': 'P000428'},
#  {'patient': 'P000430'},
#  {'patient': 'P000432'},
#  {'patient': 'P000434'},
#  {'patient': 'P000435'},
#  {'patient': 'P000433'},
#  {'patient': 'P000436'},
#  {'patient': 'P000437'},
#  {'patient': 'P000438'},
#  {'patient': 'P000441'},
#  {'patient': 'P000442'},
#  {'patient': 'P000443'},
#  {'patient': 'P000444'},
#  {'patient': 'P000445'},
#  {'patient': 'P000446'},
#  {'patient': 'P000447'},
#  {'patient': 'P000449'},
#  {'patient': 'P000451'},
#  {'patient': 'P000452'},
#  {'patient': 'P000453'},
#  {'patient': 'P000454'},
#  {'patient': 'P000455'},
#  {'patient': 'P000456'},
#  {'patient': 'P000457'},
#  {'patient': 'P000458'},
#  {'patient': 'P000459'},
#  {'patient': 'P000460'},
#  {'patient': 'P000462'},
#  {'patient': 'P000465'},
#  {'patient': 'P000466'},
#  {'patient': 'P000468'},
#  {'patient': 'P000469'},
#  {'patient': 'P000470'},
#  {'patient': 'P000471'},
#  {'patient': 'P000472'},
#  {'patient': 'P000473'},
#  {'patient': 'P000474'},
#  {'patient': 'P000476'},
#  {'patient': 'P000477'},
#  {'patient': 'P000479'},
#  {'patient': 'P000478'},
#  {'patient': 'P000480'},
#  {'patient': 'P000481'},
#  {'patient': 'P000482'},
#  {'patient': 'P000486'},
#  {'patient': 'P000487'},
#  {'patient': 'P000488'},
#  {'patient': 'P000489'},
#  {'patient': 'P000491'},
#  {'patient': 'P000492'},
#  {'patient': 'P000496'},
#  {'patient': 'P000497'},
#  {'patient': 'P000499'},
#  {'patient': 'P000500'},
#  {'patient': 'P000503'},
#  {'patient': 'P000504'},
#  {'patient': 'P000505'},
#  {'patient': 'P000506'},
#  {'patient': 'P000507'},
#  {'patient': 'P000508'},
#  {'patient': 'P000509'},
#  {'patient': 'P000511'},
#  {'patient': 'P000512'},
#  {'patient': 'P000513'},
#  {'patient': 'P000514'},
#  {'patient': 'P000518'},
#  {'patient': 'P000521'},
#  {'patient': 'P000522'},
#  {'patient': 'P000523'},
#  {'patient': 'P000524'},
#  {'patient': 'P000525'},
#  {'patient': 'P000527'},
#  {'patient': 'P000530'},
#  {'patient': 'P000531'},
#  {'patient': 'P000532'},
#  {'patient': 'P000535'},
#  {'patient': 'P000537'},
#  {'patient': 'P000538'},
#  {'patient': 'P000539'},
#  {'patient': 'P000540'},
#  {'patient': 'P000541'},
#  {'patient': 'P000543'},
#  {'patient': 'P000544'},
#  {'patient': 'P000545'},
#  {'patient': 'P000547'},
#  {'patient': 'P000548'},
#  {'patient': 'P000550'},
#  {'patient': 'P000552'},
#  {'patient': 'P000553'},
#  {'patient': 'P000554'},
#  {'patient': 'P000555'},
#  {'patient': 'P000556'},
#  {'patient': 'P000558'},
#  {'patient': 'P000559'},
#  {'patient': 'P000560'},
#  {'patient': 'P000563'},
#  {'patient': 'P000564'},
#  {'patient': 'P000566'},
#  {'patient': 'P000567'},
#  {'patient': 'P000568'},
#  {'patient': 'P000569'},
#  {'patient': 'P000570'},
#  {'patient': 'P000571'},
#  {'patient': 'P000573'},
#  {'patient': 'P000577'},
#  {'patient': 'P000578'},
#  {'patient': 'P000579'},
#  {'patient': 'P000581'},
#  {'patient': 'P000582'},
#  {'patient': 'P000583'},
#  {'patient': 'P000584'},
#  {'patient': 'P000585'},
#  {'patient': 'P000586'},
#  {'patient': 'P000589'},
#  {'patient': 'P000590'},
#  {'patient': 'P000591'},
#  {'patient': 'P000593'},
#  {'patient': 'P000592'},
#  {'patient': 'P000594'},
#  {'patient': 'P000595'},
#  {'patient': 'P000596'},
#  {'patient': 'P000597'},
#  {'patient': 'P000598'},
#  {'patient': 'P000600'},
#  {'patient': 'P000601'},
#  {'patient': 'P000602'},
#  {'patient': 'P000603'},
#  {'patient': 'P000605'},
#  {'patient': 'P000607'},
#  {'patient': 'P000609'},
#  {'patient': 'P000611'},
#  {'patient': 'P000612'},
#  {'patient': 'P000613'},
#  {'patient': 'P000614'},
#  {'patient': 'P000616'},
#  {'patient': 'P000618'},
#  {'patient': 'P000622'},
#  {'patient': 'P000626'},
#  {'patient': 'P000627'},
#  {'patient': 'P000629'},
#  {'patient': 'P000631'},
#  {'patient': 'P000632'},
#  {'patient': 'P000634'},
#  {'patient': 'P000635'},
#  {'patient': 'P000636'},
#  {'patient': 'P000637'},
#  {'patient': 'P000638'},
#  {'patient': 'P000639'},
#  {'patient': 'P000640'},
#  {'patient': 'P000643'},
#  {'patient': 'P000646'},
#  {'patient': 'P000647'},
#  {'patient': 'P000648'},
#  {'patient': 'P000652'},
#  {'patient': 'P000653'},
#  {'patient': 'P000654'},
#  {'patient': 'P000656'},
#  {'patient': 'P000659'},
#  {'patient': 'P000660'},
#  {'patient': 'P000661'},
#  {'patient': 'P000662'},
#  {'patient': 'P000663'},
#  {'patient': 'P000664'},
#  {'patient': 'P000665'},
#  {'patient': 'P000666'},
#  {'patient': 'P000667'},
#  {'patient': 'P000668'},
#  {'patient': 'P000669'},
#  {'patient': 'P000670'},
#  {'patient': 'P000672'},
#  {'patient': 'P000673'},
#  {'patient': 'P000674'},
#  {'patient': 'P000676'},
#  {'patient': 'P000677'},
#  {'patient': 'P000678'},
#  {'patient': 'P000680'},
#  {'patient': 'P000681'},
#  {'patient': 'P000682'},
#  {'patient': 'P000683'},
#  {'patient': 'P000684'},
#  {'patient': 'P000685'},
#  {'patient': 'P000687'},
#  {'patient': 'P000688'},
#  {'patient': 'P000689'},
#  {'patient': 'P000690'},
#  {'patient': 'P000691'},
#  {'patient': 'P000693'},
#  {'patient': 'P000694'},
#  {'patient': 'P000697'},
#  {'patient': 'P000698'},
#  {'patient': 'P000699'},
#  {'patient': 'P000700'},
#  {'patient': 'P000701'},
#  {'patient': 'P000703'},
#  {'patient': 'P000704'},
#  {'patient': 'P000705'},
#  {'patient': 'P000706'},
#  {'patient': 'P000707'},
#  {'patient': 'P000708'},
#  {'patient': 'P000709'},
#  {'patient': 'P000710'},
#  {'patient': 'P000711'},
#  {'patient': 'P000712'},
#  {'patient': 'P000717'},
#  {'patient': 'P000718'},
#  {'patient': 'P000719'},
#  {'patient': 'P000720'},
#  {'patient': 'P000721'},
#  {'patient': 'P000722'},
#  {'patient': 'P000723'},
#  {'patient': 'P000725'},
#  {'patient': 'P000728'},
#  {'patient': 'P000729'},
#  {'patient': 'P000731'},
#  {'patient': 'P000732'},
#  {'patient': 'P000733'},
#  {'patient': 'P000736'},
#  {'patient': 'P000737'},
#  {'patient': 'P000738'},
#  {'patient': 'P000740'},
#  {'patient': 'P000741'},
#  {'patient': 'P000743'},
#  {'patient': 'P000745'},
#  {'patient': 'P000746'},
#  {'patient': 'P000747'},
#  {'patient': 'P000750'},
#  {'patient': 'P000751'},
#  {'patient': 'P000753'},
#  {'patient': 'P000754'},
#  {'patient': 'P000755'},
#  {'patient': 'P000757'},
#  {'patient': 'P000758'},
#  {'patient': 'P000759'},
#  {'patient': 'P000760'},
#  {'patient': 'P000765'},
#  {'patient': 'P000767'},
#  {'patient': 'P000768'},
#  {'patient': 'P000772'},
#  {'patient': 'P000775'},
#  {'patient': 'P000779'},
#  {'patient': 'P000780'},
#  {'patient': 'P000781'},
#  {'patient': 'P000784'},
#  {'patient': 'P000785'},
#  {'patient': 'P000786'},
#  {'patient': 'P000787'},
#  {'patient': 'P000789'},
#  {'patient': 'P000793'},
#  {'patient': 'P000795'},
#  {'patient': 'P000796'},
#  {'patient': 'P000798'},
#  {'patient': 'P000799'},
#  {'patient': 'P000800'},
#  {'patient': 'P000805'},
#  {'patient': 'P000807'},
#  {'patient': 'P000809'},
#  {'patient': 'P000810'},
#  {'patient': 'P000812'},
#  {'patient': 'P000815'},
#  {'patient': 'P000816'},
#  {'patient': 'P000817'},
#  {'patient': 'P000819'},
#  {'patient': 'P000820'},
#  {'patient': 'P000822'},
#  {'patient': 'P000826'},
#  {'patient': 'P000827'},
#  {'patient': 'P000828'},
#  {'patient': 'P000831'},
#  {'patient': 'P000832'},
#  {'patient': 'P000834'},
#  {'patient': 'P000835'},
#  {'patient': 'P000836'},
#  {'patient': 'P000837'},
#  {'patient': 'P000838'},
#  {'patient': 'P000839'},
#  {'patient': 'P000840'},
#  {'patient': 'P000843'},
#  {'patient': 'P000844'},
#  {'patient': 'P000845'},
#  {'patient': 'P000846'},
#  {'patient': 'P000847'},
#  {'patient': 'P000848'},
#  {'patient': 'P000849'},
#  {'patient': 'P000850'},
#  {'patient': 'P000851'},
#  {'patient': 'P000852'},
#  {'patient': 'P000853'},
#  {'patient': 'P000855'},
#  {'patient': 'P000857'},
#  {'patient': 'P000858'},
#  {'patient': 'P000859'},
#  {'patient': 'P000860'},
#  {'patient': 'P000861'},
#  {'patient': 'P000863'},
#  {'patient': 'P000865'},
#  {'patient': 'P000868'},
#  {'patient': 'P000869'},
#  {'patient': 'P000870'},
#  {'patient': 'P000872'},
#  {'patient': 'P000873'},
#  {'patient': 'P000875'},
#  {'patient': 'P000876'},
#  {'patient': 'P000877'},
#  {'patient': 'P000878'},
#  {'patient': 'P000879'},
#  {'patient': 'P000880'},
#  {'patient': 'P000882'},
#  {'patient': 'P000885'},
#  {'patient': 'P000886'},
#  {'patient': 'P000887'},
#  {'patient': 'P000890'},
#  {'patient': 'P000891'},
#  {'patient': 'P000892'},
#  {'patient': 'P000893'},
#  {'patient': 'P000894'},
#  {'patient': 'P000896'},
#  {'patient': 'P000897'},
#  {'patient': 'P000898'},
#  {'patient': 'P000899'},
#  {'patient': 'P000900'},
#  {'patient': 'P000901'},
#  {'patient': 'P000902'},
#  {'patient': 'P000903'},
#  {'patient': 'P000905'},
#  {'patient': 'P000907'},
#  {'patient': 'P000908'},
#  {'patient': 'P000909'},
#  {'patient': 'P000914'},
#  {'patient': 'P000915'},
#  {'patient': 'P000917'},
#  {'patient': 'P000918'},
#  {'patient': 'P000920'},
#  {'patient': 'P000921'},
#  {'patient': 'P000922'},
#  {'patient': 'P000924'},
#  {'patient': 'P000925'},
#  {'patient': 'P000926'},
#  {'patient': 'P000928'},
#  {'patient': 'P000929'},
#  {'patient': 'P000930'},
#  {'patient': 'P000931'},
#  {'patient': 'P000933'},
#  {'patient': 'P000934'},
#  {'patient': 'P000935'},
#  {'patient': 'P000936'},
#  {'patient': 'P000937'},
#  {'patient': 'P000938'},
#  {'patient': 'P000940'},
#  {'patient': 'P000941'},
#  {'patient': 'P000943'},
#  {'patient': 'P000945'},
#  {'patient': 'P000946'},
#  {'patient': 'P000950'},
#  {'patient': 'P000951'},
#  {'patient': 'P000952'},
#  {'patient': 'P000954'},
#  {'patient': 'P000955'},
#  {'patient': 'P000956'},
#  {'patient': 'P000957'},
#  {'patient': 'P000958'},
#  {'patient': 'P000959'},
#  {'patient': 'P000960'},
#  {'patient': 'P000961'},
#  {'patient': 'P000962'},
#  {'patient': 'P000963'},
#  {'patient': 'P000964'},
#  {'patient': 'P000965'},
#  {'patient': 'P000967'},
#  {'patient': 'P000969'},
#  {'patient': 'P000970'},
#  {'patient': 'P000972'},
#  {'patient': 'P000973'},
#  {'patient': 'P000976'},
#  {'patient': 'P000977'},
#  {'patient': 'P000978'},
#  {'patient': 'P000979'},
#  {'patient': 'P000981'},
#  {'patient': 'P000982'},
#  {'patient': 'P000983'},
#  {'patient': 'P000984'},
#  {'patient': 'P000988'},
#  {'patient': 'P000989'},
#  {'patient': 'P000991'},
#  {'patient': 'P000992'},
#  {'patient': 'P000994'},
#  {'patient': 'P000996'},
#  {'patient': 'P000998'},
#  {'patient': 'P000999'},
#  {'patient': 'P001000'},
#  {'patient': 'P001001'},
#  {'patient': 'P001002'},
#  {'patient': 'P001004'},
#  {'patient': 'P001006'},
#  {'patient': 'P001005'},
#  {'patient': 'P001007'},
#  {'patient': 'P001008'},
#  {'patient': 'P001009'},
#  {'patient': 'P001010'},
#  {'patient': 'P001011'},
#  {'patient': 'P001012'},
#  {'patient': 'P001013'},
#  {'patient': 'P001014'},
#  {'patient': 'P001015'},
#  {'patient': 'P001016'},
#  {'patient': 'P001017'},
#  {'patient': 'P001018'},
#  {'patient': 'P001019'},
#  {'patient': 'P001020'},
#  {'patient': 'P001021'},
#  {'patient': 'P001022'},
#  {'patient': 'P001023'},
#  {'patient': 'P001024'},
#  {'patient': 'P001025'},
#  {'patient': 'P001026'},
#  {'patient': 'P001027'},
#  {'patient': 'P001028'},
#  {'patient': 'P001029'},
#  {'patient': 'P001030'},
#  {'patient': 'P001032'},
#  {'patient': 'P001033'},
#  {'patient': 'P001034'},
#  {'patient': 'P001035'},
#  {'patient': 'P001036'},
#  {'patient': 'P001037'},
#  {'patient': 'P001038'},
#  {'patient': 'P001039'},
#  {'patient': 'P001040'},
#  {'patient': 'P001042'},
#  {'patient': 'P001041'},
#  {'patient': 'P001043'},
#  {'patient': 'P001044'},
#  {'patient': 'P001045'},
#  {'patient': 'P001046'},
#  {'patient': 'P001048'},
#  {'patient': 'P001047'},
#  {'patient': 'P001049'},
#  {'patient': 'P001051'},
#  {'patient': 'P001052'},
#  {'patient': 'P001053'},
#  {'patient': 'P001054'},
#  {'patient': 'P001055'},
#  {'patient': 'P001057'},
#  {'patient': 'P001058'},
#  {'patient': 'P001059'},
#  {'patient': 'P001060'},
#  {'patient': 'P001062'},
#  {'patient': 'P001064'},
#  {'patient': 'P001065'},
#  {'patient': 'P001067'},
#  {'patient': 'P001069'},
#  {'patient': 'P001070'},
#  {'patient': 'P001072'},
#  {'patient': 'P001075'},
#  {'patient': 'P001076'},
#  {'patient': 'P001078'},
#  {'patient': 'P001079'},
#  {'patient': 'P001080'},
#  {'patient': 'P001081'},
#  {'patient': 'P001082'},
#  {'patient': 'P001083'},
#  {'patient': 'P001087'},
#  {'patient': 'P001089'},
#  {'patient': 'P001090'},
#  {'patient': 'P001091'},
#  {'patient': 'P001092'},
#  {'patient': 'P001093'},
#  {'patient': 'P001094'},
#  {'patient': 'P001099'},
#  {'patient': 'P001100'},
#  {'patient': 'P001101'},
#  {'patient': 'P001102'},
#  {'patient': 'P001104'},
#  {'patient': 'P001105'},
#  {'patient': 'P001106'},
#  {'patient': 'P001107'},
#  {'patient': 'P001108'},
#  {'patient': 'P001109'},
#  {'patient': 'P001110'},
#  {'patient': 'P001111'},
#  {'patient': 'P001114'},
#  {'patient': 'P001116'},
#  {'patient': 'P001117'},
#  {'patient': 'P001119'},
#  {'patient': 'P001121'},
#  {'patient': 'P001122'},
#  {'patient': 'P001123'},
#  {'patient': 'P001125'},
#  {'patient': 'P001126'},
#  {'patient': 'P001128'},
#  {'patient': 'P001129'},
#  {'patient': 'P001133'},
#  {'patient': 'P001134'},
#  {'patient': 'P001135'},
#  {'patient': 'P001140'},
#  {'patient': 'P001141'},
#  {'patient': 'P001142'},
#  {'patient': 'P001143'},
#  {'patient': 'P001144'},
#  {'patient': 'P001145'},
#  {'patient': 'P001146'},
#  {'patient': 'P001147'},
#  {'patient': 'P001148'},
#  {'patient': 'P001149'},
#  {'patient': 'P001152'},
#  {'patient': 'P001154'},
#  {'patient': 'P001155'},
#  {'patient': 'P001156'},
#  {'patient': 'P001157'},
#  {'patient': 'P001159'},
#  {'patient': 'P001160'},
#  {'patient': 'P001161'},
#  {'patient': 'P001164'},
#  {'patient': 'P001165'},
#  {'patient': 'P001166'},
#  {'patient': 'P001167'},
#  {'patient': 'P001169'},
#  {'patient': 'P001170'},
#  {'patient': 'P001172'},
#  {'patient': 'P001173'},
#  {'patient': 'P001174'},
#  {'patient': 'P001175'},
#  {'patient': 'P001177'},
#  {'patient': 'P001179'},
#  {'patient': 'P001180'},
#  {'patient': 'P001181'},
#  {'patient': 'P001183'},
#  {'patient': 'P001184'},
#  {'patient': 'P001185'},
#  {'patient': 'P001188'},
#  {'patient': 'P001189'},
#  {'patient': 'P001190'},
#  {'patient': 'P001194'},
#  {'patient': 'P001195'},
#  {'patient': 'P001196'},
#  {'patient': 'P001197'},
#  {'patient': 'P001198'},
#  {'patient': 'P001200'},
#  {'patient': 'P001202'},
#  {'patient': 'P001203'},
#  {'patient': 'P001208'},
#  {'patient': 'P001210'},
#  {'patient': 'P001211'},
#  {'patient': 'P001212'},
#  {'patient': 'P001213'},
#  {'patient': 'P001215'},
#  {'patient': 'P001216'},
#  {'patient': 'P001218'},
#  {'patient': 'P001219'},
#  {'patient': 'P001223'},
#  {'patient': 'P001225'},
#  {'patient': 'P001226'},
#  {'patient': 'P001227'},
#  {'patient': 'P001228'},
#  {'patient': 'P001229'},
#  {'patient': 'P001230'},
#  {'patient': 'P001233'},
#  {'patient': 'P001235'},
#  {'patient': 'P001236'},
#  {'patient': 'P001238'},
#  {'patient': 'P001239'},
#  {'patient': 'P001241'},
#  {'patient': 'P001242'},
#  {'patient': 'P001244'},
#  {'patient': 'P001245'},
#  {'patient': 'P001246'},
#  {'patient': 'P001247'},
#  {'patient': 'P001248'},
#  {'patient': 'P001249'},
#  {'patient': 'P001250'},
#  {'patient': 'P001251'},
#  {'patient': 'P001253'},
#  {'patient': 'P001254'},
#  {'patient': 'P001255'},
#  {'patient': 'P001256'},
#  {'patient': 'P001258'},
#  {'patient': 'P001259'},
#  {'patient': 'P001261'},
#  {'patient': 'P001262'},
#  {'patient': 'P001265'},
#  {'patient': 'P001266'},
#  {'patient': 'P001267'},
#  {'patient': 'P001269'},
#  {'patient': 'P001271'},
#  {'patient': 'P001272'},
#  {'patient': 'P001273'},
#  {'patient': 'P001274'},
#  {'patient': 'P001275'},
#  {'patient': 'P001276'},
#  {'patient': 'P001277'},
#  {'patient': 'P001278'},
#  {'patient': 'P001279'},
#  {'patient': 'P001280'},
#  {'patient': 'P001281'},
#  {'patient': 'P001282'},
#  {'patient': 'P001283'},
#  {'patient': 'P001284'},
#  {'patient': 'P001285'},
#  {'patient': 'P001287'},
#  {'patient': 'P001288'},
#  {'patient': 'P001290'},
#  {'patient': 'P001291'},
#  {'patient': 'P001293'},
#  {'patient': 'P001294'},
#  {'patient': 'P001295'},
#  {'patient': 'P001296'},
#  {'patient': 'P001299'},
#  {'patient': 'P001300'},
#  {'patient': 'P001303'},
#  {'patient': 'P001304'},
#  {'patient': 'P001305'},
#  {'patient': 'P001307'},
#  {'patient': 'P001308'},
#  {'patient': 'P001309'},
#  {'patient': 'P001310'},
#  {'patient': 'P001311'},
#  {'patient': 'P001312'},
#  {'patient': 'P001313'},
#  {'patient': 'P001314'},
#  {'patient': 'P001315'},
#  {'patient': 'P001316'},
#  {'patient': 'P001317'},
#  {'patient': 'P001318'},
#  {'patient': 'P001319'},
#  {'patient': 'P001321'},
#  {'patient': 'P001322'},
#  {'patient': 'P001325'},
#  {'patient': 'P001326'},
#  {'patient': 'P001327'},
#  {'patient': 'P001332'},
#  {'patient': 'P001334'},
#  {'patient': 'P001336'},
#  {'patient': 'P001337'},
#  {'patient': 'P001338'},
#  {'patient': 'P001340'},
#  {'patient': 'P001341'},
#  {'patient': 'P001342'},
#  {'patient': 'P001343'},
#  {'patient': 'P001344'},
#  {'patient': 'P001345'},
#  {'patient': 'P001346'},
#  {'patient': 'P001349'},
#  {'patient': 'P001350'},
#  {'patient': 'P001352'},
#  {'patient': 'P001355'},
#  {'patient': 'P001356'},
#  {'patient': 'P001358'},
#  {'patient': 'P001360'},
#  {'patient': 'P001361'},
#  {'patient': 'P001364'},
#  {'patient': 'P001366'},
#  {'patient': 'P001368'},
#  {'patient': 'P001367'},
#  {'patient': 'P001371'},
#  {'patient': 'P001372'},
#  {'patient': 'P001375'},
#  {'patient': 'P001376'},
#  {'patient': 'P001379'},
#  {'patient': 'P001380'},
#  {'patient': 'P001382'},
#  {'patient': 'P001384'},
#  {'patient': 'P001385'},
#  {'patient': 'P001387'},
#  {'patient': 'P001390'},
#  {'patient': 'P001392'},
#  {'patient': 'P001393'},
#  {'patient': 'P001395'},
#  {'patient': 'P001396'},
#  {'patient': 'P001397'},
#  {'patient': 'P001398'},
#  {'patient': 'P001399'},
#  {'patient': 'P001400'},
#  {'patient': 'P001402'},
#  {'patient': 'P001403'},
#  {'patient': 'P001404'},
#  {'patient': 'P001405'},
#  {'patient': 'P001406'},
#  {'patient': 'P001408'},
#  {'patient': 'P001410'},
#  {'patient': 'P001411'},
#  {'patient': 'P001412'},
#  {'patient': 'P001415'},
#  {'patient': 'P001416'},
#  {'patient': 'P001417'},
#  ...]

# %%
#10. Create an aggregation pipeline to obtain COVID-19 patients who also had ‘Cough (finding)’ and ‘Fever (finding)’. 
#(1) 5334 patients included

cdt.count_documents({'$and': 
                     [{'conditions': 'COVID-19'}, 
                      {'conditions': 'Cough (finding)'}, 
                      {'conditions': 'Fever (finding)'}]
                    })
# Out:
# 5334

# %%
#(2) the list of these patients

list(cdt.find({'$and': [{'conditions': 'COVID-19'}, {'conditions': 'Cough (finding)'}, {'conditions': 'Fever (finding)'}]}))
# Out:
# [{'_id': 'E000005',
#   'patient': 'P000002',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Diarrhea symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000009',
#   'patient': 'P000003',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Fatigue (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000010',
#   'patient': 'P000004',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000011',
#   'patient': 'P000005',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000028',
#   'patient': 'P000011',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000036',
#   'patient': 'P000013',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000041',
#   'patient': 'P000014',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000046',
#   'patient': 'P000015',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000057',
#   'patient': 'P000017',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Diarrhea symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000068',
#   'patient': 'P000020',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000079',
#   'patient': 'P000022',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000094',
#   'patient': 'P000024',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000100',
#   'patient': 'P000026',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000102',
#   'patient': 'P000027',
#   'conditions': ['Cough (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000104',
#   'patient': 'P000028',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000117',
#   'patient': 'P000031',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000126',
#   'patient': 'P000034',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000130',
#   'patient': 'P000035',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000143',
#   'patient': 'P000036',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000145',
#   'patient': 'P000037',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000149',
#   'patient': 'P000038',
#   'conditions': ['Cough (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000151',
#   'patient': 'P000039',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000152',
#   'patient': 'P000040',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000154',
#   'patient': 'P000041',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000158',
#   'patient': 'P000042',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000169',
#   'patient': 'P000044',
#   'conditions': ['Cough (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000174',
#   'patient': 'P000045',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000178',
#   'patient': 'P000047',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000179',
#   'patient': 'P000048',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000183',
#   'patient': 'P000049',
#   'conditions': ['Cough (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000192',
#   'patient': 'P000051',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000199',
#   'patient': 'P000055',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000203',
#   'patient': 'P000057',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Hemoptysis (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000206',
#   'patient': 'P000058',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000216',
#   'patient': 'P000061',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000246',
#   'patient': 'P000067',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000250',
#   'patient': 'P000068',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000254',
#   'patient': 'P000069',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000257',
#   'patient': 'P000070',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000263',
#   'patient': 'P000072',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000300',
#   'patient': 'P000078',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000315',
#   'patient': 'P000082',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000330',
#   'patient': 'P000087',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000354',
#   'patient': 'P000091',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000365',
#   'patient': 'P000092',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000373',
#   'patient': 'P000093',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000382',
#   'patient': 'P000095',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000384',
#   'patient': 'P000096',
#   'conditions': ['Cough (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000415',
#   'patient': 'P000105',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000429',
#   'patient': 'P000109',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000438',
#   'patient': 'P000111',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000448',
#   'patient': 'P000114',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Diarrhea symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000451',
#   'patient': 'P000115',
#   'conditions': ['Cough (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000457',
#   'patient': 'P000116',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Hemoptysis (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000459',
#   'patient': 'P000117',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000464',
#   'patient': 'P000119',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000465',
#   'patient': 'P000118',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000469',
#   'patient': 'P000120',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000479',
#   'patient': 'P000122',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000485',
#   'patient': 'P000123',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000496',
#   'patient': 'P000125',
#   'conditions': ['Cough (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000501',
#   'patient': 'P000126',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000517',
#   'patient': 'P000129',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000520',
#   'patient': 'P000130',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000527',
#   'patient': 'P000133',
#   'conditions': ['Cough (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000545',
#   'patient': 'P000138',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000550',
#   'patient': 'P000139',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000566',
#   'patient': 'P000142',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fatigue (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000574',
#   'patient': 'P000145',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Diarrhea symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000603',
#   'patient': 'P000152',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000607',
#   'patient': 'P000154',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000611',
#   'patient': 'P000156',
#   'conditions': ['Cough (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000617',
#   'patient': 'P000158',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000624',
#   'patient': 'P000161',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000630',
#   'patient': 'P000162',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000637',
#   'patient': 'P000163',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000642',
#   'patient': 'P000166',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000647',
#   'patient': 'P000167',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000660',
#   'patient': 'P000171',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000663',
#   'patient': 'P000172',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000676',
#   'patient': 'P000174',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000685',
#   'patient': 'P000177',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000692',
#   'patient': 'P000178',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000697',
#   'patient': 'P000180',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000706',
#   'patient': 'P000182',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000719',
#   'patient': 'P000186',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000729',
#   'patient': 'P000190',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000731',
#   'patient': 'P000191',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000734',
#   'patient': 'P000192',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000738',
#   'patient': 'P000193',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000742',
#   'patient': 'P000194',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000745',
#   'patient': 'P000195',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000756',
#   'patient': 'P000198',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000772',
#   'patient': 'P000203',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000774',
#   'patient': 'P000204',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000794',
#   'patient': 'P000207',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000795',
#   'patient': 'P000208',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000797',
#   'patient': 'P000209',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000809',
#   'patient': 'P000212',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000815',
#   'patient': 'P000213',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000832',
#   'patient': 'P000217',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000843',
#   'patient': 'P000220',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000849',
#   'patient': 'P000222',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000853',
#   'patient': 'P000224',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000863',
#   'patient': 'P000225',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000868',
#   'patient': 'P000227',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000869',
#   'patient': 'P000228',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000886',
#   'patient': 'P000231',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000893',
#   'patient': 'P000233',
#   'conditions': ['Nasal congestion (finding)',
#    'Headache (finding)',
#    'Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000901',
#   'patient': 'P000234',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000905',
#   'patient': 'P000235',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000920',
#   'patient': 'P000237',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000958',
#   'patient': 'P000245',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000961',
#   'patient': 'P000246',
#   'conditions': ['Cough (finding)',
#    'Diarrhea symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000984',
#   'patient': 'P000250',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000986',
#   'patient': 'P000251',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E000993',
#   'patient': 'P000253',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001014',
#   'patient': 'P000258',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001042',
#   'patient': 'P000262',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001082',
#   'patient': 'P000273',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001100',
#   'patient': 'P000275',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001105',
#   'patient': 'P000276',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001120',
#   'patient': 'P000279',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001135',
#   'patient': 'P000281',
#   'conditions': ['Cough (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001139',
#   'patient': 'P000283',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001141',
#   'patient': 'P000284',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001152',
#   'patient': 'P000287',
#   'conditions': ['Cough (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001162',
#   'patient': 'P000290',
#   'conditions': ['Cough (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001176',
#   'patient': 'P000293',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001195',
#   'patient': 'P000297',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001202',
#   'patient': 'P000299',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001203',
#   'patient': 'P000300',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001204',
#   'patient': 'P000301',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001220',
#   'patient': 'P000305',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001225',
#   'patient': 'P000306',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001234',
#   'patient': 'P000308',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Hemoptysis (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001246',
#   'patient': 'P000311',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001247',
#   'patient': 'P000312',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001259',
#   'patient': 'P000314',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001263',
#   'patient': 'P000315',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001301',
#   'patient': 'P000323',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001307',
#   'patient': 'P000325',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001310',
#   'patient': 'P000326',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001343',
#   'patient': 'P000334',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001350',
#   'patient': 'P000335',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001352',
#   'patient': 'P000336',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001364',
#   'patient': 'P000338',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001370',
#   'patient': 'P000340',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001394',
#   'patient': 'P000345',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001397',
#   'patient': 'P000344',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Diarrhea symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001402',
#   'patient': 'P000347',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001415',
#   'patient': 'P000349',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001417',
#   'patient': 'P000350',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001426',
#   'patient': 'P000353',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001451',
#   'patient': 'P000359',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Diarrhea symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001456',
#   'patient': 'P000361',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001459',
#   'patient': 'P000362',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001463',
#   'patient': 'P000364',
#   'conditions': ['Cough (finding)',
#    'Hemoptysis (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001466',
#   'patient': 'P000366',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001481',
#   'patient': 'P000371',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001486',
#   'patient': 'P000372',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001488',
#   'patient': 'P000373',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001491',
#   'patient': 'P000374',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fatigue (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001507',
#   'patient': 'P000376',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001517',
#   'patient': 'P000378',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001536',
#   'patient': 'P000382',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001540',
#   'patient': 'P000383',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001548',
#   'patient': 'P000385',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001578',
#   'patient': 'P000391',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001587',
#   'patient': 'P000392',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001625',
#   'patient': 'P000398',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001629',
#   'patient': 'P000399',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001637',
#   'patient': 'P000401',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001653',
#   'patient': 'P000405',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001663',
#   'patient': 'P000410',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Sputum finding (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001678',
#   'patient': 'P000411',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001686',
#   'patient': 'P000413',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001690',
#   'patient': 'P000414',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001708',
#   'patient': 'P000418',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001718',
#   'patient': 'P000419',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001721',
#   'patient': 'P000420',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001742',
#   'patient': 'P000423',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001748',
#   'patient': 'P000425',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001749',
#   'patient': 'P000426',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001751',
#   'patient': 'P000427',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001759',
#   'patient': 'P000428',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001773',
#   'patient': 'P000430',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001790',
#   'patient': 'P000434',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001794',
#   'patient': 'P000435',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001796',
#   'patient': 'P000433',
#   'conditions': ['Cough (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001800',
#   'patient': 'P000436',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001801',
#   'patient': 'P000437',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001805',
#   'patient': 'P000438',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001823',
#   'patient': 'P000441',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001826',
#   'patient': 'P000442',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001832',
#   'patient': 'P000443',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001842',
#   'patient': 'P000444',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001849',
#   'patient': 'P000445',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001850',
#   'patient': 'P000446',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001855',
#   'patient': 'P000447',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001869',
#   'patient': 'P000451',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001879',
#   'patient': 'P000453',
#   'conditions': ['Cough (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001881',
#   'patient': 'P000454',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001883',
#   'patient': 'P000455',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001887',
#   'patient': 'P000456',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001893',
#   'patient': 'P000457',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001896',
#   'patient': 'P000458',
#   'conditions': ['Cough (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001904',
#   'patient': 'P000462',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001935',
#   'patient': 'P000468',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001943',
#   'patient': 'P000470',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001959',
#   'patient': 'P000472',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001963',
#   'patient': 'P000473',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001967',
#   'patient': 'P000474',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001975',
#   'patient': 'P000476',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001982',
#   'patient': 'P000479',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001987',
#   'patient': 'P000480',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E001991',
#   'patient': 'P000481',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E002014',
#   'patient': 'P000487',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E002023',
#   'patient': 'P000491',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E002025',
#   'patient': 'P000492',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E002047',
#   'patient': 'P000496',
#   'conditions': ['Cough (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E002055',
#   'patient': 'P000497',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E002064',
#   'patient': 'P000500',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E002072',
#   'patient': 'P000504',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E002077',
#   'patient': 'P000506',
# ...
#    'COVID-19']},
#  {'_id': 'E009177',
#   'patient': 'P002128',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009182',
#   'patient': 'P002129',
#   'conditions': ['Cough (finding)',
#    'Hemoptysis (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009206',
#   'patient': 'P002135',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009223',
#   'patient': 'P002139',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009241',
#   'patient': 'P002142',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009243',
#   'patient': 'P002143',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009253',
#   'patient': 'P002145',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009263',
#   'patient': 'P002146',
#   'conditions': ['Cough (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009267',
#   'patient': 'P002147',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009282',
#   'patient': 'P002152',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Fatigue (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009297',
#   'patient': 'P002158',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009298',
#   'patient': 'P002159',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009303',
#   'patient': 'P002161',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009326',
#   'patient': 'P002166',
#   'conditions': ['Cough (finding)',
#    'Hemoptysis (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009330',
#   'patient': 'P002167',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009348',
#   'patient': 'P002170',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009356',
#   'patient': 'P002171',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009368',
#   'patient': 'P002173',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009382',
#   'patient': 'P002178',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009384',
#   'patient': 'P002179',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009387',
#   'patient': 'P002181',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009406',
#   'patient': 'P002184',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fatigue (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009417',
#   'patient': 'P002186',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Diarrhea symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009427',
#   'patient': 'P002189',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009434',
#   'patient': 'P002191',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009449',
#   'patient': 'P002194',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Diarrhea symptom (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009468',
#   'patient': 'P002198',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009502',
#   'patient': 'P002206',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009510',
#   'patient': 'P002208',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009513',
#   'patient': 'P002209',
#   'conditions': ['Cough (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009536',
#   'patient': 'P002213',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009543',
#   'patient': 'P002214',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009557',
#   'patient': 'P002217',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009567',
#   'patient': 'P002218',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009601',
#   'patient': 'P002222',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009607',
#   'patient': 'P002223',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009612',
#   'patient': 'P002224',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009635',
#   'patient': 'P002229',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009642',
#   'patient': 'P002230',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009645',
#   'patient': 'P002231',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009669',
#   'patient': 'P002237',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009672',
#   'patient': 'P002239',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009680',
#   'patient': 'P002240',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009687',
#   'patient': 'P002241',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009691',
#   'patient': 'P002242',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009695',
#   'patient': 'P002243',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009706',
#   'patient': 'P002247',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009709',
#   'patient': 'P002248',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009715',
#   'patient': 'P002249',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009746',
#   'patient': 'P002254',
#   'conditions': ['Cough (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009751',
#   'patient': 'P002255',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009755',
#   'patient': 'P002256',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009758',
#   'patient': 'P002257',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009779',
#   'patient': 'P002264',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Sputum finding (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009789',
#   'patient': 'P002266',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009795',
#   'patient': 'P002269',
#   'conditions': ['Cough (finding)',
#    'Diarrhea symptom (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009798',
#   'patient': 'P002270',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009800',
#   'patient': 'P002271',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009804',
#   'patient': 'P002272',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009815',
#   'patient': 'P002273',
#   'conditions': ['Cough (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009822',
#   'patient': 'P002276',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Chill (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009826',
#   'patient': 'P002277',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009833',
#   'patient': 'P002279',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Diarrhea symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009841',
#   'patient': 'P002281',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009844',
#   'patient': 'P002282',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009868',
#   'patient': 'P002286',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009873',
#   'patient': 'P002287',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Diarrhea symptom (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009876',
#   'patient': 'P002288',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009889',
#   'patient': 'P002290',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009917',
#   'patient': 'P002296',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009921',
#   'patient': 'P002297',
#   'conditions': ['Cough (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  {'_id': 'E009926',
#   'patient': 'P002299',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19']},
#  ...]

# %%
#11. Create a new aggregation pipeline to join patient data for 8,820 COVID-19 patients. 
#(1) 8463 alive COVID-19 patients

len(list(cdt.aggregate(
    [
        {
            '$lookup': {
                'from': 'patients_clean', 
                'localField': 'patient',
                'foreignField': '_id',
                'as': 'detail'
            }
        },
        {
            '$match': {
                'conditions': 'COVID-19'
            }
        },
        {
            '$match': {
                'detail': {'$ne':[]}
            }
        }
    ]
)))
# Out:
# 8463

# %%
#(2) the first 5 patients

list(cdt.aggregate(
    [
        {
            '$lookup': {
                'from': 'patients_clean', 
                'localField': 'patient',
                'foreignField': '_id',
                'as': 'detail'
            }
        },
        {
            '$match': {
                'conditions': 'COVID-19'
            }
        },
        {
            '$match': {
                'detail': {'$ne':[]}
            }
        },
        {
            '$limit': 5
        }
    ]
))
# Out:
# [{'_id': 'E000003',
#   'patient': 'P000001',
#   'conditions': ['Fever (finding)', 'Suspected COVID-19', 'COVID-19'],
#   'detail': [{'_id': 'P000001',
#     'BIRTHDATE': datetime.datetime(2017, 8, 24, 0, 0),
#     'MARITAL': nan,
#     'RACE': 'white',
#     'ETHNICITY': 'nonhispanic',
#     'GENDER': 'M',
#     'CITY': 'Springfield',
#     'COUNTY': 'Hampden County',
#     'STATE': 'Massachusetts',
#     'AGE': 6}]},
#  {'_id': 'E000005',
#   'patient': 'P000002',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Diarrhea symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19'],
#   'detail': [{'_id': 'P000002',
#     'BIRTHDATE': datetime.datetime(2016, 8, 1, 0, 0),
#     'MARITAL': nan,
#     'RACE': 'white',
#     'ETHNICITY': 'nonhispanic',
#     'GENDER': 'F',
#     'CITY': 'Walpole',
#     'COUNTY': 'Norfolk County',
#     'STATE': 'Massachusetts',
#     'AGE': 7}]},
#  {'_id': 'E000009',
#   'patient': 'P000003',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Fatigue (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19'],
#   'detail': [{'_id': 'P000003',
#     'BIRTHDATE': datetime.datetime(1992, 6, 30, 0, 0),
#     'MARITAL': 'S',
#     'RACE': 'white',
#     'ETHNICITY': 'nonhispanic',
#     'GENDER': 'M',
#     'CITY': 'Chicopee',
#     'COUNTY': 'Hampden County',
#     'STATE': 'Massachusetts',
#     'AGE': 31}]},
#  {'_id': 'E000010',
#   'patient': 'P000004',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19'],
#   'detail': [{'_id': 'P000004',
#     'BIRTHDATE': datetime.datetime(2004, 1, 9, 0, 0),
#     'MARITAL': nan,
#     'RACE': 'white',
#     'ETHNICITY': 'nonhispanic',
#     'GENDER': 'F',
#     'CITY': 'Pembroke',
#     'COUNTY': 'Plymouth County',
#     'STATE': 'Massachusetts',
#     'AGE': 19}]},
#  {'_id': 'E000011',
#   'patient': 'P000005',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19'],
#   'detail': [{'_id': 'P000005',
#     'BIRTHDATE': datetime.datetime(1996, 11, 15, 0, 0),
#     'MARITAL': nan,
#     'RACE': 'white',
#     'ETHNICITY': 'nonhispanic',
#     'GENDER': 'M',
#     'CITY': 'Boston',
#     'COUNTY': 'Suffolk County',
#     'STATE': 'Massachusetts',
#     'AGE': 27}]}]

# %%
#12. Based on the previous pipeline, create a new pipeline to calculate the total number of 
#alive COVID-19 patients for each gender.
#(1) 3992 Males

len(list(cdt.aggregate(
    [
        {
            '$lookup': {
                'from': 'patients_clean', 
                'localField': 'patient',
                'foreignField': '_id',
                'as': 'detail'
            }
        },
        {
            '$match': {
                'conditions': 'COVID-19'
            }
        },
        {
            '$match': {
                'detail': {'$ne':[]}
            }
        },
        {
            '$match': {
                'detail.GENDER': 'M'
            }
        }
    ]
)))
# Out:
# 3992

# %%
#the first 5 male patients

list(cdt.aggregate(
    [
        {
            '$lookup': {
                'from': 'patients_clean', 
                'localField': 'patient',
                'foreignField': '_id',
                'as': 'detail'
            }
        },
        {
            '$match': {
                'conditions': 'COVID-19'
            }
        },
        {
            '$match': {
                'detail': {'$ne':[]}
            }
        },
        {
            '$match': {
                'detail.GENDER': 'M'
            }
        },
        {
            '$limit': 5
        }
    ]
))
# Out:
# [{'_id': 'E000003',
#   'patient': 'P000001',
#   'conditions': ['Fever (finding)', 'Suspected COVID-19', 'COVID-19'],
#   'detail': [{'_id': 'P000001',
#     'BIRTHDATE': datetime.datetime(2017, 8, 24, 0, 0),
#     'MARITAL': nan,
#     'RACE': 'white',
#     'ETHNICITY': 'nonhispanic',
#     'GENDER': 'M',
#     'CITY': 'Springfield',
#     'COUNTY': 'Hampden County',
#     'STATE': 'Massachusetts',
#     'AGE': 6}]},
#  {'_id': 'E000009',
#   'patient': 'P000003',
#   'conditions': ['Headache (finding)',
#    'Cough (finding)',
#    'Fatigue (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19'],
#   'detail': [{'_id': 'P000003',
#     'BIRTHDATE': datetime.datetime(1992, 6, 30, 0, 0),
#     'MARITAL': 'S',
#     'RACE': 'white',
#     'ETHNICITY': 'nonhispanic',
#     'GENDER': 'M',
#     'CITY': 'Chicopee',
#     'COUNTY': 'Hampden County',
#     'STATE': 'Massachusetts',
#     'AGE': 31}]},
#  {'_id': 'E000011',
#   'patient': 'P000005',
#   'conditions': ['Nasal congestion (finding)',
#    'Cough (finding)',
#    'Sputum finding (finding)',
#    'Fatigue (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19'],
#   'detail': [{'_id': 'P000005',
#     'BIRTHDATE': datetime.datetime(1996, 11, 15, 0, 0),
#     'MARITAL': nan,
#     'RACE': 'white',
#     'ETHNICITY': 'nonhispanic',
#     'GENDER': 'M',
#     'CITY': 'Boston',
#     'COUNTY': 'Suffolk County',
#     'STATE': 'Massachusetts',
#     'AGE': 27}]},
#  {'_id': 'E000015',
#   'patient': 'P000007',
#   'conditions': ['Headache (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19'],
#   'detail': [{'_id': 'P000007',
#     'BIRTHDATE': datetime.datetime(1983, 12, 12, 0, 0),
#     'MARITAL': 'M',
#     'RACE': 'white',
#     'ETHNICITY': 'nonhispanic',
#     'GENDER': 'M',
#     'CITY': 'Somerville',
#     'COUNTY': 'Middlesex County',
#     'STATE': 'Massachusetts',
#     'AGE': 40}]},
#  {'_id': 'E000019',
#   'patient': 'P000008',
#   'conditions': ['Cough (finding)',
#    'Sore throat symptom (finding)',
#    'Fatigue (finding)',
#    'Suspected COVID-19',
#    'COVID-19'],
#   'detail': [{'_id': 'P000008',
#     'BIRTHDATE': datetime.datetime(1989, 6, 22, 0, 0),
#     'MARITAL': 'M',
#     'RACE': 'white',
#     'ETHNICITY': 'hispanic',
#     'GENDER': 'M',
#     'CITY': 'Chicopee',
#     'COUNTY': 'Hampden County',
#     'STATE': 'Massachusetts',
#     'AGE': 34}]}]

# %%
#(2) 4471 Females

len(list(cdt.aggregate(
    [
        {
            '$lookup': {
                'from': 'patients_clean', 
                'localField': 'patient',
                'foreignField': '_id',
                'as': 'detail'
            }
        },
        {
            '$match': {
                'conditions': 'COVID-19'
            }
        },
        {
            '$match': {
                'detail': {'$ne':[]}
            }
        },
        {
            '$match': {
                'detail.GENDER': 'F'
            }
        }
    ]
)))
# Out:
# 4471

# %%
#the first 5 female patients

list(cdt.aggregate(
    [
        {
            '$lookup': {
                'from': 'patients_clean', 
                'localField': 'patient',
                'foreignField': '_id',
                'as': 'detail'
            }
        },
        {
            '$match': {
                'conditions': 'COVID-19'
            }
        },
        {
            '$match': {
                'detail': {'$ne':[]}
            }
        },
        {
            '$match': {
                'detail.GENDER': 'F'
            }
        },
        {
            '$limit': 5
        }
    ]
))
# Out:
# [{'_id': 'E000005',
#   'patient': 'P000002',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Diarrhea symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19'],
#   'detail': [{'_id': 'P000002',
#     'BIRTHDATE': datetime.datetime(2016, 8, 1, 0, 0),
#     'MARITAL': nan,
#     'RACE': 'white',
#     'ETHNICITY': 'nonhispanic',
#     'GENDER': 'F',
#     'CITY': 'Walpole',
#     'COUNTY': 'Norfolk County',
#     'STATE': 'Massachusetts',
#     'AGE': 7}]},
#  {'_id': 'E000010',
#   'patient': 'P000004',
#   'conditions': ['Cough (finding)',
#    'Sputum finding (finding)',
#    'Nausea (finding)',
#    'Vomiting symptom (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19'],
#   'detail': [{'_id': 'P000004',
#     'BIRTHDATE': datetime.datetime(2004, 1, 9, 0, 0),
#     'MARITAL': nan,
#     'RACE': 'white',
#     'ETHNICITY': 'nonhispanic',
#     'GENDER': 'F',
#     'CITY': 'Pembroke',
#     'COUNTY': 'Plymouth County',
#     'STATE': 'Massachusetts',
#     'AGE': 19}]},
#  {'_id': 'E000012',
#   'patient': 'P000006',
#   'conditions': ['Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19'],
#   'detail': [{'_id': 'P000006',
#     'BIRTHDATE': datetime.datetime(2019, 6, 12, 0, 0),
#     'MARITAL': nan,
#     'RACE': 'white',
#     'ETHNICITY': 'nonhispanic',
#     'GENDER': 'F',
#     'CITY': 'Colrain',
#     'COUNTY': 'Franklin County',
#     'STATE': 'Massachusetts',
#     'AGE': 4}]},
#  {'_id': 'E000024',
#   'patient': 'P000009',
#   'conditions': ['Muscle pain (finding)',
#    'Joint pain (finding)',
#    'Fever (finding)',
#    'Loss of taste (finding)',
#    'Suspected COVID-19',
#    'COVID-19'],
#   'detail': [{'_id': 'P000009',
#     'BIRTHDATE': datetime.datetime(1991, 7, 31, 0, 0),
#     'MARITAL': 'M',
#     'RACE': 'white',
#     'ETHNICITY': 'nonhispanic',
#     'GENDER': 'F',
#     'CITY': 'Medfield',
#     'COUNTY': 'Norfolk County',
#     'STATE': 'Massachusetts',
#     'AGE': 32}]},
#  {'_id': 'E000028',
#   'patient': 'P000011',
#   'conditions': ['Cough (finding)',
#    'Fatigue (finding)',
#    'Dyspnea (finding)',
#    'Wheezing (finding)',
#    'Fever (finding)',
#    'Suspected COVID-19',
#    'COVID-19'],
#   'detail': [{'_id': 'P000011',
#     'BIRTHDATE': datetime.datetime(1978, 6, 24, 0, 0),
#     'MARITAL': 'M',
#     'RACE': 'white',
#     'ETHNICITY': 'nonhispanic',
#     'GENDER': 'F',
#     'CITY': 'Lowell',
#     'COUNTY': 'Middlesex County',
#     'STATE': 'Massachusetts',
#     'AGE': 45}]}]
